# %%
import sys

# %% [markdown]
# # Persuasive Technical News Detection Task
#
# 專案描述 \
# 這個專案採用 PyTorch Lightning 框架，執行 NLP4IF2019 News 分類任務。訓練和驗證過程會上傳至 Weights & Biases (wandb) 平台，並在驗證階段計算混淆矩陣（confusion matrix）和 AUC（Area Under the Curve）分數。
#
# NLP4IF2019 News 資料集介紹 \
# NLP4IF2019 News 資料集是由NLP4IF2019 share task收集並整理的一個新聞數據集，數據集包括350篇訓練文章、61篇開發文章和86篇測試文章，共有1,2000 Passages。這些文章均來自48家不同的新聞媒體。文章中的片段被標註了18種宣傳技術之一。
#
# 資料集特點： \
# 數據量： 12000 條新聞評論 \
# 標籤：多標籤分類（multi-label classification），即18種宣傳技術 \
# 語言：英文（English） \
# 應用場景：文本分類（text classification）
#
# github : https://github.com/Tariq60/propaganda-nlp4if2019

# %%
project = 'PersuTech-adapter-4c-DIL'
model_name_or_path = 'cardiffnlp/twitter-roberta-large-2022-154m' #'FacebookAI/roberta-large'
task_name = "roberta-Adapter-CE,len=256"

# %% [markdown]
# ## Traing phase

# %%
# !{sys.executable} ../script/train_multiclass.py --project {project} \
--model_name_or_path {model_name_or_path} \
--task_name {task_name} \
--version 'FD' \
--strategy 'random' \
--output_dir 'models' \
--train_dataset '../data/NLP4IF2019/Encoder-based-hierarchical/train' \
--test_dataset '../data/NLP4IF2019/Encoder-based-hierarchical/test'
# Out:
# /user_data/envs/adapter/lib/python3.8/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of RobertaAdapterModel were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-large-2022-154m and are newly initialized: ['heads.default.3.bias', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [0.7385019710906702, 0.316688567674113, 0.16294349540078842, 0.2588699080157687]
# [0.7385019710906702, 0.433311432325887, 0.5870565045992115, 0.4911300919842313]
# Some weights of RobertaModel were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-large-2022-154m and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Conver to Embeddings: 100%|██████████████████| 761/761 [00:01<00:00, 455.42it/s]
# /user_data/envs/adapter/lib/python3.8/site-packages/adapters/composition.py:186: FutureWarning: Passing list objects for adapter activation is deprecated. Please use Stack or Fuse explicitly.
#   warnings.warn(
# /user_data/envs/adapter/lib/python3.8/site-packages/pytorch_lightning/utilities/parsing.py:208: Attribute 'adapter_model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['adapter_model'])`.
# focal loss, alpha
# [0.7385019710906702, 0.433311432325887, 0.5870565045992115, 0.4911300919842313]
# ContrastiveLearningModel(
#   (encoder): RobertaAdapterModel(
#     (roberta): RobertaModel(
#       (embeddings): RobertaEmbeddings(
#         (word_embeddings): Embedding(50265, 1024, padding_idx=1)
#         (position_embeddings): Embedding(514, 1024, padding_idx=1)
#         (token_type_embeddings): Embedding(1, 1024)
#         (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (encoder): RobertaEncoder(
#         (layer): ModuleList(
#           (0-23): 24 x RobertaLayer(
#             (attention): RobertaAttention(
#               (self): RobertaSelfAttentionWithAdapters(
#                 (query): LoRALinearTorch(
#                   in_features=1024, out_features=1024, bias=True
#                   (loras): ModuleDict()
#                 )
#                 (key): LoRALinearTorch(
#                   in_features=1024, out_features=1024, bias=True
#                   (loras): ModuleDict()
#                 )
#                 (value): LoRALinearTorch(
#                   in_features=1024, out_features=1024, bias=True
#                   (loras): ModuleDict()
#                 )
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (prefix_tuning): PrefixTuningLayer(
#                   (prefix_gates): ModuleDict()
#                   (pool): PrefixTuningPool(
#                     (prefix_tunings): ModuleDict()
#                   )
#                 )
#               )
#               (output): RobertaSelfOutputWithAdapters(
#                 (dense): Linear(in_features=1024, out_features=1024, bias=True)
#                 (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (adapters): ModuleDict()
#                 (adapter_fusion_layer): ModuleDict()
#               )
#             )
#             (intermediate): RobertaIntermediate(
#               (dense): LoRALinearTorch(
#                 in_features=1024, out_features=4096, bias=True
#                 (loras): ModuleDict()
#               )
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): RobertaOutputWithAdapters(
#               (dense): LoRALinearTorch(
#                 in_features=4096, out_features=1024, bias=True
#                 (loras): ModuleDict()
#               )
#               (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (adapters): ModuleDict(
#                 (task_adapter): Adapter(
#                   (non_linearity): Activation_Function_Class(
#                     (f): ReLU()
#                   )
#                   (adapter_down): Sequential(
#                     (0): Linear(in_features=1024, out_features=64, bias=True)
#                     (1): Activation_Function_Class(
#                       (f): ReLU()
#                     )
#                   )
#                   (adapter_up): Linear(in_features=64, out_features=1024, bias=True)
#                   (dropout): Dropout(p=0.0, inplace=False)
#                 )
#               )
#               (adapter_fusion_layer): ModuleDict()
#             )
#             (reft_layer): ReftLayer(
#               (refts): ModuleDict()
#             )
#           )
#         )
#       )
#       (pooler): RobertaPooler(
#         (dense): Linear(in_features=1024, out_features=1024, bias=True)
#         (activation): Tanh()
#       )
#       (invertible_adapters): ModuleDict()
#       (shared_parameters): ModuleDict()
#       (prefix_tuning): PrefixTuningPool(
#         (prefix_tunings): ModuleDict()
#       )
#       (prompt_tuning): PromptTuningLayer(
#         (base_model_embeddings): Embedding(50265, 1024, padding_idx=1)
#         (prompt_tunings): ModuleDict()
#       )
#     )
#     (heads): ModuleDict(
#       (default): BertStyleMaskedLMHead(
#         (0): Linear(in_features=1024, out_features=1024, bias=True)
#         (1): Activation_Function_Class(
#           (f): GELUActivation()
#         )
#         (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (3): Linear(in_features=1024, out_features=50265, bias=True)
#       )
#       (task_adapter): ClassificationHead(
#         (0): Dropout(p=0.1, inplace=False)
#         (1): Linear(in_features=1024, out_features=1024, bias=True)
#         (2): Activation_Function_Class(
#           (f): Tanh()
#         )
#         (3): Dropout(p=0.1, inplace=False)
#         (4): Linear(in_features=1024, out_features=4, bias=True)
#       )
#     )
#   )
# )
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /user_data/envs/adapter/lib/python3.8/site-packages/pytorch_lightning/utilities/parsing.py:44: Attribute 'adapter_model' removed from hparams because it cannot be pickled. You can suppress this warning by setting `self.save_hyperparameters(ignore=['adapter_model'])`.
# wandb: Currently logged in as: swguo. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.18.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.17.5
# wandb: Run data is saved locally in ./wandb/run-20240919_170456-ebiah4i6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run roberta-Adapter-CE,len=256_FD_random
# wandb: ⭐️ View project at https://wandb.ai/swguo/PersuTech-adapter-4c-DIL
# wandb: 🚀 View run at https://wandb.ai/swguo/PersuTech-adapter-4c-DIL/runs/ebiah4i6
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# /user_data/envs/adapter/lib/python3.8/site-packages/transformers/optimization.py:591: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#
#   | Name    | Type                | Params | Mode
# -------------------------------------------------------
# 0 | encoder | RobertaAdapterModel | 360 M  | eval
# -------------------------------------------------------
# 5.3 M     Trainable params
# 355 M     Non-trainable params
# 360 M     Total params
# 1,442.749 Total estimated model params size (MB)
# Epoch 0:  53%|▌| 100/190 [00:15<00:13,  6.59it/s, v_num=h4i6, train_loss_step=1.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:20,  1.88it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:19,  1.87it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:19,  1.87it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:18,  1.87it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:18,  1.87it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:17,  1.87it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.87it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:16,  1.86it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:04<00:16,  1.86it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:15,  1.86it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:05<00:15,  1.86it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:14,  1.86it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:06<00:13,  1.86it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.86it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:12,  1.86it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.86it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:11,  1.86it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:09<00:11,  1.86it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:10,  1.86it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:10<00:10,  1.86it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:09,  1.86it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:11<00:09,  1.86it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.86it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:12<00:08,  1.86it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.86it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:13<00:06,  1.86it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:14<00:06,  1.86it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:05,  1.86it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:15<00:05,  1.86it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:04,  1.86it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:16<00:04,  1.86it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.86it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:17<00:03,  1.86it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:18<00:02,  1.86it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:18<00:02,  1.86it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:19<00:01,  1.86it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:19<00:01,  1.86it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:20<00:00,  1.86it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:20<00:00,  1.88it/s]Metric val_loss improved. New best score: 1.387
#
# Epoch 1:  53%|▌| 100/190 [00:15<00:14,  6.27it/s, v_num=h4i6, train_loss_step=1.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:20,  1.85it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.84it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:19,  1.84it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.84it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:18,  1.82it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.83it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.83it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:16,  1.83it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:04<00:16,  1.83it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:15,  1.83it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.83it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:14,  1.83it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.83it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.83it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.83it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.83it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.83it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:09<00:11,  1.83it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:10,  1.83it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:10<00:10,  1.83it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:09,  1.83it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.83it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.83it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.83it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.83it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.83it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:14<00:06,  1.83it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.83it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:15<00:05,  1.83it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:04,  1.83it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:16<00:04,  1.83it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.83it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.83it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:18<00:02,  1.83it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.83it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:19<00:01,  1.83it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.83it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:20<00:00,  1.83it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.85it/s]
# Epoch 2:  53%|▌| 100/190 [00:15<00:14,  6.25it/s, v_num=h4i6, train_loss_step=1.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:20,  1.83it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.82it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:19,  1.82it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.81it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:18,  1.81it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.81it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.81it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.81it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:04<00:16,  1.81it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:15,  1.81it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.81it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:14,  1.81it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.81it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.81it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.81it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.81it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.81it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:09<00:11,  1.81it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.81it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:11<00:10,  1.81it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:09,  1.81it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.81it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.81it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.81it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.81it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.81it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:14<00:06,  1.81it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.81it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.81it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:04,  1.81it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.81it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.81it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.81it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:18<00:02,  1.81it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.81it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:19<00:01,  1.81it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.81it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:20<00:00,  1.81it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.83it/s]Metric val_loss improved by 0.006 >= min_delta = 0.0. New best score: 1.381
#
# Epoch 3:  53%|▌| 100/190 [00:16<00:14,  6.24it/s, v_num=h4i6, train_loss_step=1.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:20,  1.81it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.80it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:20,  1.80it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.80it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:18,  1.80it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.80it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.80it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.80it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:04<00:16,  1.80it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:16,  1.80it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.80it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:14,  1.80it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.80it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.80it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.80it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.80it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.80it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:09<00:11,  1.80it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.80it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:09,  1.80it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.80it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.80it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.80it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.80it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.80it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:14<00:06,  1.80it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.80it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.80it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:04,  1.80it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.80it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.80it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.80it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:18<00:02,  1.80it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.80it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:20<00:01,  1.80it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.80it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:21<00:00,  1.80it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.82it/s]Metric val_loss improved by 0.071 >= min_delta = 0.0. New best score: 1.311
#
# Epoch 4:  53%|▌| 100/190 [00:16<00:14,  6.19it/s, v_num=h4i6, train_loss_step=0.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:20,  1.81it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.80it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:20,  1.80it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.80it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:18,  1.80it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.80it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.79it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.79it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.79it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.79it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.79it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.79it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.79it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.79it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.79it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.79it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.79it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.79it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.79it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.79it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.79it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:18<00:02,  1.79it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.79it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:21<00:00,  1.79it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.81it/s]Metric val_loss improved by 0.108 >= min_delta = 0.0. New best score: 1.203
#
# Epoch 5:  53%|▌| 100/190 [00:16<00:14,  6.16it/s, v_num=h4i6, train_loss_step=0.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:20,  1.81it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.80it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:20,  1.80it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.80it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:18,  1.80it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.79it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.79it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.79it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.79it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.79it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.79it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.79it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.79it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.79it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.79it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.79it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.79it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.79it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.79it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.79it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.79it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:18<00:02,  1.79it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.79it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:21<00:00,  1.79it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.81it/s]Metric val_loss improved by 0.014 >= min_delta = 0.0. New best score: 1.188
#
# Epoch 6:  53%|▌| 100/190 [00:16<00:14,  6.20it/s, v_num=h4i6, train_loss_step=1.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:21,  1.80it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.79it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:20,  1.79it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.79it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:18,  1.79it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.79it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.79it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.79it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.79it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.79it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.79it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.79it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.79it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.79it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.79it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.79it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.79it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.79it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.79it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.79it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.79it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:18<00:02,  1.79it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.79it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:21<00:00,  1.79it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.81it/s]Metric val_loss improved by 0.006 >= min_delta = 0.0. New best score: 1.182
#
# Epoch 7:  53%|▌| 100/190 [00:16<00:14,  6.16it/s, v_num=h4i6, train_loss_step=0.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:21,  1.81it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.80it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:20,  1.79it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.78it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:19,  1.79it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.79it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.79it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.79it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:16,  1.79it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:15,  1.79it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.79it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:13,  1.79it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.79it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.79it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.79it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.79it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:10,  1.79it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.79it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.79it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.79it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:13<00:07,  1.79it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.79it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.79it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:05,  1.79it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.79it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.79it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.79it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:19<00:02,  1.79it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.79it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.79it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:21<00:00,  1.79it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.81it/s]Metric val_loss improved by 0.016 >= min_delta = 0.0. New best score: 1.166
#
# Epoch 8:  53%|▌| 100/190 [00:16<00:14,  6.15it/s, v_num=h4i6, train_loss_step=1.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:21,  1.80it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.79it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:20,  1.79it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.79it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:19,  1.79it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.79it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.79it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.79it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:05<00:16,  1.78it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:16,  1.78it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.78it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:15,  1.78it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.78it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:14,  1.78it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.78it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.78it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.78it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:10<00:11,  1.78it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.78it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:11<00:10,  1.78it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:10,  1.78it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.78it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.78it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.78it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:14<00:07,  1.78it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.78it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:15<00:06,  1.78it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.78it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.78it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:05,  1.78it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.78it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.78it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.78it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:19<00:02,  1.78it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.78it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:20<00:01,  1.78it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.78it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:21<00:00,  1.78it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.80it/s]Metric val_loss improved by 0.026 >= min_delta = 0.0. New best score: 1.140
#
# Epoch 9:  53%|▌| 100/190 [00:16<00:14,  6.16it/s, v_num=h4i6, train_loss_step=0.
# Validation: |                                             | 0/? [00:00<?, ?it/s]
# Validation:   0%|                                        | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/39 [00:00<?, ?it/s]
# Validation DataLoader 0:   3%|▍                  | 1/39 [00:00<00:21,  1.80it/s]
# Validation DataLoader 0:   5%|▉                  | 2/39 [00:01<00:20,  1.79it/s]
# Validation DataLoader 0:   8%|█▍                 | 3/39 [00:01<00:20,  1.79it/s]
# Validation DataLoader 0:  10%|█▉                 | 4/39 [00:02<00:19,  1.78it/s]
# Validation DataLoader 0:  13%|██▍                | 5/39 [00:02<00:19,  1.79it/s]
# Validation DataLoader 0:  15%|██▉                | 6/39 [00:03<00:18,  1.78it/s]
# Validation DataLoader 0:  18%|███▍               | 7/39 [00:03<00:17,  1.79it/s]
# Validation DataLoader 0:  21%|███▉               | 8/39 [00:04<00:17,  1.79it/s]
# Validation DataLoader 0:  23%|████▍              | 9/39 [00:05<00:16,  1.78it/s]
# Validation DataLoader 0:  26%|████▌             | 10/39 [00:05<00:16,  1.78it/s]
# Validation DataLoader 0:  28%|█████             | 11/39 [00:06<00:15,  1.78it/s]
# Validation DataLoader 0:  31%|█████▌            | 12/39 [00:06<00:15,  1.78it/s]
# Validation DataLoader 0:  33%|██████            | 13/39 [00:07<00:14,  1.78it/s]
# Validation DataLoader 0:  36%|██████▍           | 14/39 [00:07<00:14,  1.78it/s]
# Validation DataLoader 0:  38%|██████▉           | 15/39 [00:08<00:13,  1.78it/s]
# Validation DataLoader 0:  41%|███████▍          | 16/39 [00:08<00:12,  1.78it/s]
# Validation DataLoader 0:  44%|███████▊          | 17/39 [00:09<00:12,  1.78it/s]
# Validation DataLoader 0:  46%|████████▎         | 18/39 [00:10<00:11,  1.78it/s]
# Validation DataLoader 0:  49%|████████▊         | 19/39 [00:10<00:11,  1.78it/s]
# Validation DataLoader 0:  51%|█████████▏        | 20/39 [00:11<00:10,  1.78it/s]
# Validation DataLoader 0:  54%|█████████▋        | 21/39 [00:11<00:10,  1.78it/s]
# Validation DataLoader 0:  56%|██████████▏       | 22/39 [00:12<00:09,  1.78it/s]
# Validation DataLoader 0:  59%|██████████▌       | 23/39 [00:12<00:08,  1.78it/s]
# Validation DataLoader 0:  62%|███████████       | 24/39 [00:13<00:08,  1.78it/s]
# Validation DataLoader 0:  64%|███████████▌      | 25/39 [00:14<00:07,  1.78it/s]
# Validation DataLoader 0:  67%|████████████      | 26/39 [00:14<00:07,  1.78it/s]
# Validation DataLoader 0:  69%|████████████▍     | 27/39 [00:15<00:06,  1.78it/s]
# Validation DataLoader 0:  72%|████████████▉     | 28/39 [00:15<00:06,  1.78it/s]
# Validation DataLoader 0:  74%|█████████████▍    | 29/39 [00:16<00:05,  1.78it/s]
# Validation DataLoader 0:  77%|█████████████▊    | 30/39 [00:16<00:05,  1.78it/s]
# Validation DataLoader 0:  79%|██████████████▎   | 31/39 [00:17<00:04,  1.78it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 32/39 [00:17<00:03,  1.78it/s]
# Validation DataLoader 0:  85%|███████████████▏  | 33/39 [00:18<00:03,  1.78it/s]
# Validation DataLoader 0:  87%|███████████████▋  | 34/39 [00:19<00:02,  1.78it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 35/39 [00:19<00:02,  1.78it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 36/39 [00:20<00:01,  1.78it/s]
# Validation DataLoader 0:  95%|█████████████████ | 37/39 [00:20<00:01,  1.78it/s]
# Validation DataLoader 0:  97%|█████████████████▌| 38/39 [00:21<00:00,  1.78it/s]
# Validation DataLoader 0: 100%|██████████████████| 39/39 [00:21<00:00,  1.80it/s]
# Epoch 9: 100%|█| 190/190 [00:52<00:00,  3.61it/s, v_num=h4i6, train_loss_step=0.`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100%|█| 190/190 [00:52<00:00,  3.61it/s, v_num=h4i6, train_loss_step=0.
# RobertaAdapterModel(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 1024, padding_idx=1)
#       (position_embeddings): Embedding(514, 1024, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttentionWithAdapters(
#               (query): LoRALinearTorch(
#                 in_features=1024, out_features=1024, bias=True
#                 (loras): ModuleDict()
#               )
#               (key): LoRALinearTorch(
#                 in_features=1024, out_features=1024, bias=True
#                 (loras): ModuleDict()
#               )
#               (value): LoRALinearTorch(
#                 in_features=1024, out_features=1024, bias=True
#                 (loras): ModuleDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (prefix_tuning): PrefixTuningLayer(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (output): RobertaSelfOutputWithAdapters(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (adapters): ModuleDict()
#               (adapter_fusion_layer): ModuleDict()
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): LoRALinearTorch(
#               in_features=1024, out_features=4096, bias=True
#               (loras): ModuleDict()
#             )
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutputWithAdapters(
#             (dense): LoRALinearTorch(
#               in_features=4096, out_features=1024, bias=True
#               (loras): ModuleDict()
#             )
#             (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict(
#               (task_adapter): Adapter(
#                 (non_linearity): Activation_Function_Class(
#                   (f): ReLU()
#                 )
#                 (adapter_down): Sequential(
#                   (0): Linear(in_features=1024, out_features=64, bias=True)
#                   (1): Activation_Function_Class(
#                     (f): ReLU()
#                   )
#                 )
#                 (adapter_up): Linear(in_features=64, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (reft_layer): ReftLayer(
#             (refts): ModuleDict()
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#     (invertible_adapters): ModuleDict()
#     (shared_parameters): ModuleDict()
#     (prefix_tuning): PrefixTuningPool(
#       (prefix_tunings): ModuleDict()
#     )
#     (prompt_tuning): PromptTuningLayer(
#       (base_model_embeddings): Embedding(50265, 1024, padding_idx=1)
#       (prompt_tunings): ModuleDict()
#     )
#   )
#   (heads): ModuleDict(
#     (default): BertStyleMaskedLMHead(
#       (0): Linear(in_features=1024, out_features=1024, bias=True)
#       (1): Activation_Function_Class(
#         (f): GELUActivation()
#       )
#       (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=1024, out_features=50265, bias=True)
#     )
#     (task_adapter): ClassificationHead(
#       (0): Dropout(p=0.1, inplace=False)
#       (1): Linear(in_features=1024, out_features=1024, bias=True)
#       (2): Activation_Function_Class(
#         (f): Tanh()
#       )
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# /user_data/envs/adapter/lib/python3.8/site-packages/pytorch_lightning/utilities/parsing.py:208: Attribute 'adapter_model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['adapter_model'])`.
# focal loss, alpha
# [0.7385019710906702, 0.433311432325887, 0.5870565045992115, 0.4911300919842313]
# wandb: \ 0.016 MB of 0.016 MB uploaded
# wandb: Run history:
# wandb:               epoch ▁▁▁▁▂▂▂▂▃▃▃▃▃▃▃▃▄▄▄▄▅▅▅▅▆▆▆▆▆▆▆▆▇▇▇▇████
# wandb:    train_loss_epoch ██▇▆▅▄▄▃▂▁
# wandb:     train_loss_step ▇▅▆▆▆▆▆▄▆▇▅▅▆▆▅▅▅▇▆▄▄▄▆▇▃▅▄▃▄▂▅█▂▅▁▄▃▄
# wandb: trainer/global_step ▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███
# wandb:        val_accuracy ▁▁▁▅▆▇▇███
# wandb:              val_f1 ▁▁▁▅▆▇▇███
# wandb:            val_loss ███▆▃▂▂▂▁▂
# wandb:       val_precision ▁▁▁▅▆▇▇███
# wandb:          val_recall ▁▁▁▅▆▇▇███
# wandb:
# wandb: Run summary:
# wandb:               epoch 9
# wandb:    train_loss_epoch 0.59673
# wandb:     train_loss_step 0.82788
# wandb: trainer/global_step 1899
# wandb:        val_accuracy 0.55916
# wandb:              val_f1 0.55916
# wandb:            val_loss 1.17555
# wandb:       val_precision 0.55916
# wandb:          val_recall 0.55916
# wandb:
# wandb: 🚀 View run roberta-Adapter-CE,len=256_FD_random at: https://wandb.ai/swguo/PersuTech-adapter-4c-DIL/runs/ebiah4i6
# wandb: ⭐️ View project at: https://wandb.ai/swguo/PersuTech-adapter-4c-DIL
# wandb: Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240919_170456-ebiah4i6/logs
# wandb: WARNING The new W&B backend becomes opt-out in version 0.18.0; try it out with `wandb.require("core")`! See https://wandb.me/wandb-core for more information.

# %% [markdown]
# ## Inference phase

# %%
# !{sys.executable} ../script/inference.py --project {project} \
--base_model_name {model_name_or_path} \
--task_name {task_name} \
--strategy 'random' \
--version 'FD' \
--best_checkpoint 'best-checkpoint.ckpt' \
--dataset_path_or_name 'NLP4IF2019/Encoder-based-hierarchical/test/dataset'
# Out:
# /user_data/envs/adapter/lib/python3.8/site-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Some weights of RobertaAdapterModel were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-large-2022-154m and are newly initialized: ['heads.default.3.bias', 'roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The 'config' and 'model_name' arguments are specific to the now unsupported legacy Hub repo and will be removed.Please switch to only providing the HF Model Hub identifier.
# RobertaAdapterModel(
#   (roberta): RobertaModel(
#     (embeddings): RobertaEmbeddings(
#       (word_embeddings): Embedding(50265, 1024, padding_idx=1)
#       (position_embeddings): Embedding(514, 1024, padding_idx=1)
#       (token_type_embeddings): Embedding(1, 1024)
#       (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): RobertaEncoder(
#       (layer): ModuleList(
#         (0-23): 24 x RobertaLayer(
#           (attention): RobertaAttention(
#             (self): RobertaSelfAttentionWithAdapters(
#               (query): LoRALinearTorch(
#                 in_features=1024, out_features=1024, bias=True
#                 (loras): ModuleDict()
#               )
#               (key): LoRALinearTorch(
#                 in_features=1024, out_features=1024, bias=True
#                 (loras): ModuleDict()
#               )
#               (value): LoRALinearTorch(
#                 in_features=1024, out_features=1024, bias=True
#                 (loras): ModuleDict()
#               )
#               (dropout): Dropout(p=0.1, inplace=False)
#               (prefix_tuning): PrefixTuningLayer(
#                 (prefix_gates): ModuleDict()
#                 (pool): PrefixTuningPool(
#                   (prefix_tunings): ModuleDict()
#                 )
#               )
#             )
#             (output): RobertaSelfOutputWithAdapters(
#               (dense): Linear(in_features=1024, out_features=1024, bias=True)
#               (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#               (adapters): ModuleDict()
#               (adapter_fusion_layer): ModuleDict()
#             )
#           )
#           (intermediate): RobertaIntermediate(
#             (dense): LoRALinearTorch(
#               in_features=1024, out_features=4096, bias=True
#               (loras): ModuleDict()
#             )
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): RobertaOutputWithAdapters(
#             (dense): LoRALinearTorch(
#               in_features=4096, out_features=1024, bias=True
#               (loras): ModuleDict()
#             )
#             (LayerNorm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (adapters): ModuleDict(
#               (task_adapter): Adapter(
#                 (non_linearity): Activation_Function_Class(
#                   (f): ReLU()
#                 )
#                 (adapter_down): Sequential(
#                   (0): Linear(in_features=1024, out_features=64, bias=True)
#                   (1): Activation_Function_Class(
#                     (f): ReLU()
#                   )
#                 )
#                 (adapter_up): Linear(in_features=64, out_features=1024, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (adapter_fusion_layer): ModuleDict()
#           )
#           (reft_layer): ReftLayer(
#             (refts): ModuleDict()
#           )
#         )
#       )
#     )
#     (pooler): RobertaPooler(
#       (dense): Linear(in_features=1024, out_features=1024, bias=True)
#       (activation): Tanh()
#     )
#     (invertible_adapters): ModuleDict()
#     (shared_parameters): ModuleDict()
#     (prefix_tuning): PrefixTuningPool(
#       (prefix_tunings): ModuleDict()
#     )
#     (prompt_tuning): PromptTuningLayer(
#       (base_model_embeddings): Embedding(50265, 1024, padding_idx=1)
#       (prompt_tunings): ModuleDict()
#     )
#   )
#   (heads): ModuleDict(
#     (default): BertStyleMaskedLMHead(
#       (0): Linear(in_features=1024, out_features=1024, bias=True)
#       (1): Activation_Function_Class(
#         (f): GELUActivation()
#       )
#       (2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=1024, out_features=50265, bias=True)
#     )
#     (task_adapter): ClassificationHead(
#       (0): Dropout(p=0.1, inplace=False)
#       (1): Linear(in_features=1024, out_features=1024, bias=True)
#       (2): Activation_Function_Class(
#         (f): Tanh()
#       )
#       (3): Dropout(p=0.1, inplace=False)
#       (4): Linear(in_features=1024, out_features=4, bias=True)
#     )
#   )
# )
# Dataset Information
# DatasetDict({
#     test: Dataset({
#         features: ['id', 'text', 'translated_article', 'category', 'None', 'Ethos', 'Logos', 'Pathos', 'classes'],
#         num_rows: 1234
#     })
# })
# 100%|█████████████████████████████████████████| 309/309 [00:13<00:00, 22.69it/s]

# %% [markdown]
# ## Eval phase

# %%
# !{sys.executable} ../script/evaluate_multiclass.py --project {project} \
--task_name {task_name} \
--version 'FD' \
--strategy 'random' \
--base_model_name {model_name_or_path} \
--dataset_path_or_name 'prediction_FD.csv'
# Out:
# Class 0 Accuracy: 0.7073
# Class 1 Accuracy: 0.4146
# Class 2 Accuracy: 0.4037
# Class 3 Accuracy: 0.5956
